# %%
import requests
import os

# %%
import os
import requests
import pandas as pd

BASE_URL = "https://sandbox.root.co.za/v1/insurance"
BASE_URL_ROOT = "https://api.root.co.za/v1/transactions"
ROOT_APP_ID = '63ee3c38-0013-11e8-88a2-8bc71944599c'
ROOT_APP_SECRET = 'VQ8ho4cNJ3Xs_pjArQvEeNrdV9It2lxl'
#ROOT_APP_S2 = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....CaLEqzkcJ4ewYwXrjP0iZVPTN2dR9lImXxr4Y55VcIs'

def list_gadget_models():
    result = requests.get("%s/gadgets/models" % BASE_URL, auth=(ROOT_APP_ID, ROOT_APP_SECRET))
    if result.status_code == 200:
        return result.json()
    else:
        raise RootException()

pd.DataFrame(list_gadget_models())

# %%
# Out:
#           make                                               name    value
# 0         Acer  Liquid Jade 5" Quad-Core w/ Dual Sim Slots (8G...   444900
# 1      Alcatel           3003G Cellphone & Alcatel 3000 Cellphone    89900
# 2        Apple                                           iPhone 5   449900
# 3        Apple                                          iPhone 5S   449900
# 4        Apple                                  iPhone 6 16GB LTE   689900
# 5        Apple                                  iPhone 6 32GB LTE   689900
# 6        Apple                            iPhone 6 Plus 128GB LTE   999900
# 7        Apple                                iPhone 6S 128GB LTE   999900
# 8        Apple                                 iPhone 6S 32GB LTE   999900
# 9        Apple                           iPhone 6S Plus 128GB LTE  1299900
# 10       Apple                            iPhone 6S Plus 32GB LTE  1099900
# ...

# %%
# Out:
# <Response [400]>

# %%
requests.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e48f32d3c7fc> in <module>()
# ----> 1 requests.values
#
# AttributeError: module 'requests' has no attribute 'values'
